# %% [markdown]
# ## Analysis of algorithms that make exact recovery of the cluster structure in GBM
# Model description is [here](https://arxiv.org/pdf/1709.05510.pdf)
#
# Candidate algorithms are:
# 1. Motif-counting algorithm (from the above paper) and its modification from [here](https://arxiv.org/abs/1804.05013)
# 2. Spectral clustering with a smart choice of the optimal eigenvectors (k-means around optimal value)
# 3. Expansion algorithm described in my draft [here](https://www.overleaf.com/project/5e9483ae085e6600014af805)
#
# Last update: 21/05/2020

# %% [markdown]
# ### This notebook uses the classes.py file where principal classes and functions are defined
#
# File classes.py is on autoreload

# %%
import pandas as pd
import numpy as np
import networkx as nx
import random
import matplotlib.pyplot as plt
import seaborn as sns
from classes_other_matrices import GBM_graph, Motif_Counting, Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means, Spectral_clustering, Laplacian_regularization, Common_neigbours_labeling, simulation, full_simulation, k_means_analysis
import tqdm
import time 
import warnings
import copy
warnings.filterwarnings("ignore")
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Regularized laplacian with tau. $\tau$ = 0 means no modification

# %%
G = GBM_graph(n_1 = 4000, n_2 = 4000, a = 15, b = 5)

# %%
k_means_analysis(G, vectors = range(40, 55), vectors_disp = True, sigma = 0, tau = 0)
# Out:
# 0

# %%
k_means_analysis(G, vectors = [], k_means_disp = True)

# %%
k_means_analysis(G, vectors = range(40, 55), vectors_disp = True, sigma = 0, tau = 0.1)

# %%
k_means_analysis(G, vectors = range(40, 55), vectors_disp = True, sigma = 0, tau = 1)

# %%
k_means_analysis(G, vectors = range(40, 55), vectors_disp = True, sigma = 0, tau = 10)

# %%
k_means_analysis(G, vectors = range(40, 55), vectors_disp = True, sigma = 0, tau = 100)

# %%
k_means_analysis(G, vectors = range(40, 55), vectors_disp = True, sigma = 0, tau = 500)

# %% [markdown]
# ### Bethe-hessian matrix

# %%
G = GBM_graph(n_1 = 4000, n_2 = 4000, a = 15, b = 5)

# %%
k_means_analysis(G, vectors = [], vectors_disp = True)

# %%
k_means_analysis(G, vectors = range(1, 40), vectors_disp = True, xi = 0.5, h = 0.5)

# %%
k_means_analysis(G, vectors = range(1, 80), vectors_disp = True, xi = 0.3, h = 0.5)

# %%
k_means_analysis(G, vectors = range(1, 80), vectors_disp = True, xi = 0.9, h = 0.5)

# %%
k_means_analysis(G, vectors = range(1, 80), vectors_disp = True, xi = 1.5, h = 0.5)

# %%
k_means_analysis(G, vectors = range(1, 80), vectors_disp = True, xi = 0.6, h = 0.5)

# %%
k_means_analysis(G, vectors = range(1, 80), vectors_disp = True, xi = 0.4, h = 0.5)

# %%
k_means_analysis(G, vectors = range(1, 80), vectors_disp = True, xi = 0.5, h = 0.9)

# %%
k_means_analysis(G, vectors = range(1, 80), vectors_disp = True, xi = 0.5, h = 0.1)

# %%
k_means_analysis(G, vectors = range(1, 80), vectors_disp = True, xi = 0.5, h = 5)

# %%
k_means_analysis(G, vectors = range(35, 60), k_means_disp = True, xi = 0.6, h = 0.5)

# %%
k_means_analysis(G, vectors = range(1, 80), vectors_disp = True, xi = 0.4, h = 0.5)

# %%
k_means_analysis(G, vectors = range(15, 30), k_means_disp = True, xi = 0.4, h = 0.5)

# %%
k_means_analysis(G, vectors = range(7, 20), k_means_disp = True, xi = 0.3, h = 0.5)
