# %% [markdown]
# ## Analysis of algorithms that make exact recovery of the cluster structure in GBM
# Model description is [here](https://arxiv.org/pdf/1709.05510.pdf)
#
# Candidate algorithms are:
# 1. Motif-counting algorithm (from the above paper) and its modification from [here](https://arxiv.org/abs/1804.05013)
# 2. Spectral clustering with a smart choice of the optimal eigenvectors (k-means around optimal value)
# 3. Expansion algorithm described in my draft [here](https://www.overleaf.com/project/5e9483ae085e6600014af805)
#
# Last update: 21/05/2020

# %% [markdown]
# ## This is the general picture of the top three algorithms' performance

# %% [markdown]
# ### This notebook uses the classes.py file where principal classes and functions are defined
#
# File classes.py is on autoreload

# %%
import pandas as pd
import numpy as np
import networkx as nx
import random
import matplotlib.pyplot as plt
import seaborn as sns
from classes_full_picture import GBM_graph, Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means, Common_neigbours_labeling, simulation, full_simulation
import tqdm
import time 
import warnings
import copy
warnings.filterwarnings("ignore")
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
fs2_500 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 500, 
                          n_2 = 500, 
                          a_start = 2, 
                          a_finish = 15, 
                          a_step = 1, 
                          b = 2,
                          n_trials = 20)
# Out:
# a = 2, b = 2, n = 1000, Motif_Counting_second_paper = 50.0% (3sec), Expansion_algorithm = 51.0% (1sec), Spectral_k_means = 50.0% (1sec),
# a = 3, b = 2, n = 1000, Motif_Counting_second_paper = 50.0% (4sec), Expansion_algorithm = 52.0% (1sec), Spectral_k_means = 50.0% (1sec),
# a = 4, b = 2, n = 1000, Motif_Counting_second_paper = 50.0% (6sec), Expansion_algorithm = 52.0% (2sec), Spectral_k_means = 50.0% (1sec),
# a = 5, b = 2, n = 1000, Motif_Counting_second_paper = 50.0% (7sec), Expansion_algorithm = 53.0% (4sec), Spectral_k_means = 50.0% (1sec),
# a = 6, b = 2, n = 1000, Motif_Counting_second_paper = 53.0% (8sec), Expansion_algorithm = 55.0% (7sec), Spectral_k_means = 74.0% (3sec),
# a = 7, b = 2, n = 1000, Motif_Counting_second_paper = 59.0% (10sec), Expansion_algorithm = 61.0% (13sec), Spectral_k_means = 82.0% (5sec),
# a = 8, b = 2, n = 1000, Motif_Counting_second_paper = 81.0% (12sec), Expansion_algorithm = 87.0% (15sec), Spectral_k_means = 88.0% (4sec),
# ...

# %%
fs5_500 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 500, 
                          n_2 = 500, 
                          a_start = 5, 
                          a_finish = 21, 
                          a_step = 1, 
                          b = 5,
                          n_trials = 20)
# Out:
# a = 5, b = 5, n = 1000, Motif_Counting_second_paper = 50.0% (11sec), Expansion_algorithm = 51.0% (2sec), Spectral_k_means = 50.0% (2sec),
# a = 6, b = 5, n = 1000, Motif_Counting_second_paper = 51.0% (13sec), Expansion_algorithm = 51.0% (3sec), Spectral_k_means = 50.0% (2sec),
# a = 7, b = 5, n = 1000, Motif_Counting_second_paper = 51.0% (16sec), Expansion_algorithm = 51.0% (3sec), Spectral_k_means = 57.0% (3sec),
# a = 8, b = 5, n = 1000, Motif_Counting_second_paper = 59.0% (18sec), Expansion_algorithm = 51.0% (5sec), Spectral_k_means = 94.0% (4sec),
# a = 9, b = 5, n = 1000, Motif_Counting_second_paper = 87.0% (20sec), Expansion_algorithm = 52.0% (7sec), Spectral_k_means = 95.0% (4sec),
# a = 10, b = 5, n = 1000, Motif_Counting_second_paper = 95.0% (23sec), Expansion_algorithm = 55.0% (11sec), Spectral_k_means = 92.0% (5sec),
# a = 11, b = 5, n = 1000, Motif_Counting_second_paper = 97.0% (25sec), Expansion_algorithm = 62.0% (20sec), Spectral_k_means = 98.0% (4sec),
# ...

# %%
fs10_500 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 500, 
                          n_2 = 500, 
                          a_start = 10, 
                          a_finish = 26, 
                          a_step = 1, 
                          b = 10,
                          n_trials = 20)
# Out:
# a = 10, b = 10, n = 1000, Motif_Counting_second_paper = 50.0% (35sec), Expansion_algorithm = 51.0% (5sec), Spectral_k_means = 50.0% (5sec),
# a = 11, b = 10, n = 1000, Motif_Counting_second_paper = 50.0% (38sec), Expansion_algorithm = 51.0% (6sec), Spectral_k_means = 52.0% (9sec),
# a = 12, b = 10, n = 1000, Motif_Counting_second_paper = 50.0% (42sec), Expansion_algorithm = 51.0% (6sec), Spectral_k_means = 56.0% (11sec),
# a = 13, b = 10, n = 1000, Motif_Counting_second_paper = 50.0% (45sec), Expansion_algorithm = 51.0% (7sec), Spectral_k_means = 98.0% (8sec),
# a = 14, b = 10, n = 1000, Motif_Counting_second_paper = 50.0% (49sec), Expansion_algorithm = 51.0% (8sec), Spectral_k_means = 100.0% (7sec),
# a = 15, b = 10, n = 1000, Motif_Counting_second_paper = 50.0% (52sec), Expansion_algorithm = 52.0% (12sec), Spectral_k_means = 100.0% (6sec),
# a = 16, b = 10, n = 1000, Motif_Counting_second_paper = 50.0% (56sec), Expansion_algorithm = 55.0% (19sec), Spectral_k_means = 100.0% (7sec),
# ...

# %%
fs20_500 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 500, 
                          n_2 = 500, 
                          a_start = 20, 
                          a_finish = 36, 
                          a_step = 1, 
                          b = 20,
                          n_trials = 20)
# Out:
# a = 20, b = 20, n = 1000, Motif_Counting_second_paper = 50.0% (114sec), Expansion_algorithm = 51.0% (13sec), Spectral_k_means = 51.0% (17sec),
# a = 21, b = 20, n = 1000, Motif_Counting_second_paper = 50.0% (120sec), Expansion_algorithm = 51.0% (12sec), Spectral_k_means = 51.0% (19sec),
# a = 22, b = 20, n = 1000, Motif_Counting_second_paper = 50.0% (127sec), Expansion_algorithm = 51.0% (13sec), Spectral_k_means = 52.0% (19sec),
# a = 23, b = 20, n = 1000, Motif_Counting_second_paper = 50.0% (137sec), Expansion_algorithm = 51.0% (14sec), Spectral_k_means = 65.0% (18sec),
# a = 24, b = 20, n = 1000, Motif_Counting_second_paper = 50.0% (147sec), Expansion_algorithm = 51.0% (15sec), Spectral_k_means = 83.0% (15sec),
# a = 25, b = 20, n = 1000, Motif_Counting_second_paper = 50.0% (157sec), Expansion_algorithm = 51.0% (16sec), Spectral_k_means = 100.0% (12sec),
# ...

# %%
fs2_1000 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 1000, 
                          n_2 = 1000, 
                          a_start = 2, 
                          a_finish = 15, 
                          a_step = 1, 
                          b = 2,
                          n_trials = 20)
# Out:
# a = 2, b = 2, n = 2000, Motif_Counting_second_paper = 50.0% (8sec), Expansion_algorithm = 51.0% (2sec), Spectral_k_means = 50.0% (3sec),
# a = 3, b = 2, n = 2000, Motif_Counting_second_paper = 50.0% (11sec), Expansion_algorithm = 51.0% (3sec), Spectral_k_means = 50.0% (3sec),
# a = 4, b = 2, n = 2000, Motif_Counting_second_paper = 50.0% (14sec), Expansion_algorithm = 51.0% (5sec), Spectral_k_means = 50.0% (4sec),
# a = 5, b = 2, n = 2000, Motif_Counting_second_paper = 51.0% (17sec), Expansion_algorithm = 52.0% (8sec), Spectral_k_means = 50.0% (4sec),
# a = 6, b = 2, n = 2000, Motif_Counting_second_paper = 52.0% (21sec), Expansion_algorithm = 54.0% (14sec), Spectral_k_means = 71.0% (11sec),
# a = 7, b = 2, n = 2000, Motif_Counting_second_paper = 55.0% (25sec), Expansion_algorithm = 60.0% (25sec), Spectral_k_means = 70.0% (12sec),
# a = 8, b = 2, n = 2000, Motif_Counting_second_paper = 68.0% (29sec), Expansion_algorithm = 84.0% (47sec), Spectral_k_means = 78.0% (12sec),
# ...

# %%
fs5_1000 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 1000, 
                          n_2 = 1000, 
                          a_start = 5, 
                          a_finish = 21, 
                          a_step = 1, 
                          b = 5,
                          n_trials = 20)
# Out:
# a = 5, b = 5, n = 2000, Motif_Counting_second_paper = 51.0% (29sec), Expansion_algorithm = 51.0% (6sec), Spectral_k_means = 50.0% (7sec),
# a = 6, b = 5, n = 2000, Motif_Counting_second_paper = 51.0% (36sec), Expansion_algorithm = 51.0% (7sec), Spectral_k_means = 50.0% (7sec),
# a = 7, b = 5, n = 2000, Motif_Counting_second_paper = 51.0% (42sec), Expansion_algorithm = 51.0% (8sec), Spectral_k_means = 60.0% (11sec),
# a = 8, b = 5, n = 2000, Motif_Counting_second_paper = 53.0% (47sec), Expansion_algorithm = 51.0% (12sec), Spectral_k_means = 88.0% (15sec),
# a = 9, b = 5, n = 2000, Motif_Counting_second_paper = 80.0% (52sec), Expansion_algorithm = 51.0% (15sec), Spectral_k_means = 93.0% (14sec),
# a = 10, b = 5, n = 2000, Motif_Counting_second_paper = 97.0% (58sec), Expansion_algorithm = 54.0% (22sec), Spectral_k_means = 94.0% (14sec),
# a = 11, b = 5, n = 2000, Motif_Counting_second_paper = 98.0% (65sec), Expansion_algorithm = 56.0% (36sec), Spectral_k_means = 94.0% (13sec),
# ...

# %%
fs10_1000 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 1000, 
                          n_2 = 1000, 
                          a_start = 10, 
                          a_finish = 26, 
                          a_step = 1, 
                          b = 10,
                          n_trials = 20)
# Out:
# a = 10, b = 10, n = 2000, Motif_Counting_second_paper = 50.0% (90sec), Expansion_algorithm = 51.0% (13sec), Spectral_k_means = 50.0% (12sec),
# a = 11, b = 10, n = 2000, Motif_Counting_second_paper = 50.0% (99sec), Expansion_algorithm = 51.0% (15sec), Spectral_k_means = 51.0% (18sec),
# a = 12, b = 10, n = 2000, Motif_Counting_second_paper = 50.0% (108sec), Expansion_algorithm = 51.0% (15sec), Spectral_k_means = 58.0% (34sec),
# a = 13, b = 10, n = 2000, Motif_Counting_second_paper = 50.0% (118sec), Expansion_algorithm = 51.0% (17sec), Spectral_k_means = 94.0% (21sec),
# a = 14, b = 10, n = 2000, Motif_Counting_second_paper = 50.0% (128sec), Expansion_algorithm = 52.0% (22sec), Spectral_k_means = 100.0% (16sec),
# a = 15, b = 10, n = 2000, Motif_Counting_second_paper = 50.0% (137sec), Expansion_algorithm = 52.0% (30sec), Spectral_k_means = 100.0% (15sec),
# ...

# %%
fs20_1000 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 1000, 
                          n_2 = 1000, 
                          a_start = 20, 
                          a_finish = 36, 
                          a_step = 1, 
                          b = 20,
                          n_trials = 20)
# Out:
# a = 20, b = 20, n = 2000, Motif_Counting_second_paper = 50.0% (327sec), Expansion_algorithm = 51.0% (34sec), Spectral_k_means = 51.0% (48sec),
# a = 21, b = 20, n = 2000, Motif_Counting_second_paper = 50.0% (355sec), Expansion_algorithm = 51.0% (35sec), Spectral_k_means = 51.0% (62sec),
# a = 22, b = 20, n = 2000, Motif_Counting_second_paper = 50.0% (385sec), Expansion_algorithm = 51.0% (37sec), Spectral_k_means = 51.0% (64sec),
# a = 23, b = 20, n = 2000, Motif_Counting_second_paper = 50.0% (409sec), Expansion_algorithm = 51.0% (38sec), Spectral_k_means = 66.0% (54sec),
# a = 24, b = 20, n = 2000, Motif_Counting_second_paper = 50.0% (431sec), Expansion_algorithm = 51.0% (41sec), Spectral_k_means = 89.0% (44sec),
# a = 25, b = 20, n = 2000, Motif_Counting_second_paper = 50.0% (452sec), Expansion_algorithm = 51.0% (42sec), Spectral_k_means = 98.0% (35sec),
# ...

# %%
fs2_2000 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 2000, 
                          n_2 = 2000, 
                          a_start = 2, 
                          a_finish = 15, 
                          a_step = 1, 
                          b = 2,
                          n_trials = 20)
# Out:
# a = 2, b = 2, n = 4000, Motif_Counting_second_paper = 50.0% (19sec), Expansion_algorithm = 51.0% (6sec), Spectral_k_means = 50.0% (10sec),
# a = 3, b = 2, n = 4000, Motif_Counting_second_paper = 50.0% (26sec), Expansion_algorithm = 51.0% (7sec), Spectral_k_means = 50.0% (10sec),
# a = 4, b = 2, n = 4000, Motif_Counting_second_paper = 50.0% (34sec), Expansion_algorithm = 51.0% (10sec), Spectral_k_means = 50.0% (11sec),
# a = 5, b = 2, n = 4000, Motif_Counting_second_paper = 50.0% (42sec), Expansion_algorithm = 51.0% (15sec), Spectral_k_means = 56.0% (16sec),
# a = 6, b = 2, n = 4000, Motif_Counting_second_paper = 51.0% (49sec), Expansion_algorithm = 52.0% (25sec), Spectral_k_means = 59.0% (22sec),
# a = 7, b = 2, n = 4000, Motif_Counting_second_paper = 53.0% (61sec), Expansion_algorithm = 58.0% (49sec), Spectral_k_means = 62.0% (25sec),
# a = 8, b = 2, n = 4000, Motif_Counting_second_paper = 68.0% (72sec), Expansion_algorithm = 74.0% (94sec), Spectral_k_means = 67.0% (28sec),
# ...

# %%
fs5_2000 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 2000, 
                          n_2 = 2000, 
                          a_start = 5, 
                          a_finish = 21, 
                          a_step = 1, 
                          b = 5,
                          n_trials = 20)
# Out:
# a = 5, b = 5, n = 4000, Motif_Counting_second_paper = 51.0% (73sec), Expansion_algorithm = 51.0% (15sec), Spectral_k_means = 50.0% (15sec),
# a = 6, b = 5, n = 4000, Motif_Counting_second_paper = 50.0% (86sec), Expansion_algorithm = 51.0% (17sec), Spectral_k_means = 50.0% (18sec),
# a = 7, b = 5, n = 4000, Motif_Counting_second_paper = 51.0% (100sec), Expansion_algorithm = 51.0% (21sec), Spectral_k_means = 68.0% (41sec),
# a = 8, b = 5, n = 4000, Motif_Counting_second_paper = 51.0% (113sec), Expansion_algorithm = 51.0% (25sec), Spectral_k_means = 68.0% (39sec),
# a = 9, b = 5, n = 4000, Motif_Counting_second_paper = 87.0% (127sec), Expansion_algorithm = 51.0% (32sec), Spectral_k_means = 79.0% (38sec),
# a = 10, b = 5, n = 4000, Motif_Counting_second_paper = 95.0% (141sec), Expansion_algorithm = 52.0% (46sec), Spectral_k_means = 75.0% (41sec),
# ...

# %%
fs10_2000 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 2000, 
                          n_2 = 2000, 
                          a_start = 10, 
                          a_finish = 26, 
                          a_step = 1, 
                          b = 10,
                          n_trials = 20)
# Out:
# a = 10, b = 10, n = 4000, Motif_Counting_second_paper = 50.0% (215sec), Expansion_algorithm = 51.0% (32sec), Spectral_k_means = 50.0% (34sec),
# a = 11, b = 10, n = 4000, Motif_Counting_second_paper = 50.0% (237sec), Expansion_algorithm = 51.0% (35sec), Spectral_k_means = 51.0% (55sec),
# a = 12, b = 10, n = 4000, Motif_Counting_second_paper = 50.0% (260sec), Expansion_algorithm = 51.0% (37sec), Spectral_k_means = 56.0% (148sec),
# a = 13, b = 10, n = 4000, Motif_Counting_second_paper = 50.0% (282sec), Expansion_algorithm = 51.0% (41sec), Spectral_k_means = 83.0% (86sec),
# a = 14, b = 10, n = 4000, Motif_Counting_second_paper = 50.0% (304sec), Expansion_algorithm = 51.0% (48sec), Spectral_k_means = 98.0% (50sec),
# a = 15, b = 10, n = 4000, Motif_Counting_second_paper = 50.0% (327sec), Expansion_algorithm = 52.0% (63sec), Spectral_k_means = 97.0% (49sec),
# ...

# %%
fs20_2000 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 2000, 
                          n_2 = 2000, 
                          a_start = 20, 
                          a_finish = 36, 
                          a_step = 1, 
                          b = 20,
                          n_trials = 20)
# Out:
# a = 20, b = 20, n = 4000, Motif_Counting_second_paper = 50.0% (802sec), Expansion_algorithm = 51.0% (81sec), Spectral_k_means = 51.0% (107sec),
# a = 21, b = 20, n = 4000, Motif_Counting_second_paper = 50.0% (848sec), Expansion_algorithm = 51.0% (84sec), Spectral_k_means = 51.0% (190sec),
# a = 22, b = 20, n = 4000, Motif_Counting_second_paper = 50.0% (891sec), Expansion_algorithm = 51.0% (86sec), Spectral_k_means = 51.0% (219sec),
# a = 23, b = 20, n = 4000, Motif_Counting_second_paper = 50.0% (932sec), Expansion_algorithm = 51.0% (91sec), Spectral_k_means = 55.0% (237sec),
# a = 24, b = 20, n = 4000, Motif_Counting_second_paper = 50.0% (973sec), Expansion_algorithm = 51.0% (95sec), Spectral_k_means = 60.0% (208sec),
# a = 25, b = 20, n = 4000, Motif_Counting_second_paper = 50.0% (1016sec), Expansion_algorithm = 51.0% (102sec), Spectral_k_means = 100.0% (79sec),
# ...

# %%
a_array = [x['a'] for x in fs20_500]
array_500 = [x['Motif_Counting_second_paper'] for x in fs20_500]
array_1000 = [x['Motif_Counting_second_paper'] for x in fs20_1000]
array_2000 = [x['Motif_Counting_second_paper'] for x in fs20_2000]
plt.plot(a_array, array_500, label = 'n = 500')
plt.plot(a_array, array_1000, label = 'n = 1000')
plt.plot(a_array, array_2000, label = 'n = 2000')
plt.grid()
plt.legend()
plt.show()

# %%
a_array = [x['a'] for x in fs20_500]
array_500 = [x['Spectral_k_means'] for x in fs20_500]
array_1000 = [x['Spectral_k_means'] for x in fs20_1000]
array_2000 = [x['Spectral_k_means'] for x in fs20_2000]
plt.plot(a_array, array_500, label = 'n = 500')
plt.plot(a_array, array_1000, label = 'n = 1000')
plt.plot(a_array, array_2000, label = 'n = 2000')
plt.grid()
plt.legend()
plt.show()

# %%
a_array = [x['a'] for x in fs20_500]
array_500 = [x['Expansion_algorithm'] for x in fs20_500]
array_1000 = [x['Expansion_algorithm'] for x in fs20_1000]
array_2000 = [x['Expansion_algorithm'] for x in fs20_2000]
plt.plot(a_array, array_500, label = 'n = 500')
plt.plot(a_array, array_1000, label = 'n = 1000')
plt.plot(a_array, array_2000, label = 'n = 2000')
plt.grid()
plt.legend()
plt.show()

# %%
a_array = [x['a'] for x in fs2_500]
array_500 = [x['Motif_Counting_second_paper'] for x in fs2_500]
array_1000 = [x['Motif_Counting_second_paper'] for x in fs2_1000]
array_2000 = [x['Motif_Counting_second_paper'] for x in fs2_2000]
plt.plot(a_array, array_500, label = 'n = 500')
plt.plot(a_array, array_1000, label = 'n = 1000')
plt.plot(a_array, array_2000, label = 'n = 2000')
plt.grid()
plt.legend()
plt.show()

# %%
a_array = [x['a'] for x in fs2_500]
array_500 = [x['Spectral_k_means'] for x in fs2_500]
array_1000 = [x['Spectral_k_means'] for x in fs2_1000]
array_2000 = [x['Spectral_k_means'] for x in fs2_2000]
plt.plot(a_array, array_500, label = 'n = 500')
plt.plot(a_array, array_1000, label = 'n = 1000')
plt.plot(a_array, array_2000, label = 'n = 2000')
plt.grid()
plt.legend()
plt.show()

# %%
a_array = [x['a'] for x in fs2_500]
array_500 = [x['Expansion_algorithm'] for x in fs2_500]
array_1000 = [x['Expansion_algorithm'] for x in fs2_1000]
array_2000 = [x['Expansion_algorithm'] for x in fs2_2000]
plt.plot(a_array, array_500, label = 'n = 500')
plt.plot(a_array, array_1000, label = 'n = 1000')
plt.plot(a_array, array_2000, label = 'n = 2000')
plt.grid()
plt.legend()
plt.show()

# %%
fs2_2500 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 2500, 
                          n_2 = 2500, 
                          a_start = 2, 
                          a_finish = 15, 
                          a_step = 1, 
                          b = 2,
                          n_trials = 10)
# Out:
# a = 2, b = 2, n = 5000, Motif_Counting_second_paper = 50.0% (12sec), Expansion_algorithm = 50.0% (3sec), Spectral_k_means = 50.0% (8sec),
# a = 3, b = 2, n = 5000, Motif_Counting_second_paper = 50.0% (16sec), Expansion_algorithm = 51.0% (4sec), Spectral_k_means = 50.0% (7sec),
# a = 4, b = 2, n = 5000, Motif_Counting_second_paper = 50.0% (20sec), Expansion_algorithm = 51.0% (6sec), Spectral_k_means = 50.0% (7sec),
# a = 5, b = 2, n = 5000, Motif_Counting_second_paper = 50.0% (24sec), Expansion_algorithm = 51.0% (9sec), Spectral_k_means = 62.0% (14sec),
# a = 6, b = 2, n = 5000, Motif_Counting_second_paper = 51.0% (30sec), Expansion_algorithm = 52.0% (15sec), Spectral_k_means = 61.0% (15sec),
# a = 7, b = 2, n = 5000, Motif_Counting_second_paper = 54.0% (37sec), Expansion_algorithm = 56.0% (28sec), Spectral_k_means = 64.0% (16sec),
# a = 8, b = 2, n = 5000, Motif_Counting_second_paper = 63.0% (44sec), Expansion_algorithm = 78.0% (59sec), Spectral_k_means = 72.0% (17sec),
# ...

# %%
G = GBM_graph(n_1 = 500, n_2 = 500, a = 2, b = 2, disp = True)
# Out:
# average degree inside: 13.815510557964274
# average degree outside: 13.815510557964274

# %%
m = Motif_Counting_second_paper(G)

# %%
m.accuracy
# Out:
# 0.501
