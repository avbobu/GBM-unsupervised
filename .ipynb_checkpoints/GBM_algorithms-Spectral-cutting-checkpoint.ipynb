# %% [markdown]
# ## Analysis of algorithms that make exact recovery of the cluster structure in GBM
# Model description is [here](https://arxiv.org/pdf/1709.05510.pdf)
#
# Candidate algorithms are:
# 1. Motif-counting algorithm (from the above paper) and its modification from [here](https://arxiv.org/abs/1804.05013)
# 2. Spectral clustering with a smart choice of the optimal eigenvectors (k-means around optimal value)
# 3. Expansion algorithm described in my draft [here](https://www.overleaf.com/project/5e9483ae085e6600014af805)
#
# Last update: 21/05/2020

# %% [markdown]
# ### This notebook uses the classes.py file where principal classes and functions are defined
#
# File classes.py is on autoreload

# %%
import pandas as pd
import numpy as np
import networkx as nx
import random
import matplotlib.pyplot as plt
import seaborn as sns
from classes import GBM_graph, Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means, Spectral_clustering, Spectral_cutting, Spectral_cutting_2, Spectral_cutting_3, Spectral_cutting_4, Spectral_cutting_8, Common_neigbours_labeling, simulation, full_simulation, k_means_analysis
import tqdm
import time 
import warnings
import copy
warnings.filterwarnings("ignore")
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
full_simulation([Spectral_k_means], 
                b = 20, 
                a_start = 20, 
                a_finish = 30, 
                a_step = 1, 
                n_1 = 500, 
                n_2 = 500,
                n_trials = 20)
# Out:
# a = 20, b = 20, n = 1000, Spectral_k_means = 51.0% (23sec),
# a = 21, b = 20, n = 1000, Spectral_k_means = 52.0% (27sec),
# a = 22, b = 20, n = 1000, Spectral_k_means = 51.0% (27sec),
# a = 23, b = 20, n = 1000, Spectral_k_means = 73.0% (23sec),
# a = 24, b = 20, n = 1000, Spectral_k_means = 89.0% (16sec),
# a = 25, b = 20, n = 1000, Spectral_k_means = 100.0% (13sec),
# a = 26, b = 20, n = 1000, Spectral_k_means = 100.0% (13sec),
# a = 27, b = 20, n = 1000, Spectral_k_means = 100.0% (15sec),
# a = 28, b = 20, n = 1000, Spectral_k_means = 100.0% (15sec),
# a = 29, b = 20, n = 1000, Spectral_k_means = 100.0% (15sec),
# [{'Spectral_k_means': 0.5135500000000001, 'a': 20},
#  {'Spectral_k_means': 0.5183, 'a': 21},
#  {'Spectral_k_means': 0.5144500000000001, 'a': 22},
#  {'Spectral_k_means': 0.7295, 'a': 23},
#  {'Spectral_k_means': 0.8852000000000001, 'a': 24},
#  {'Spectral_k_means': 1.0000000000000002, 'a': 25},
#  {'Spectral_k_means': 1.0000000000000002, 'a': 26},
#  {'Spectral_k_means': 1.0000000000000002, 'a': 27},
#  {'Spectral_k_means': 1.0000000000000002, 'a': 28},
#  {'Spectral_k_means': 1.0000000000000002, 'a': 29}]

# %%
full_simulation([Spectral_k_means], 
                b = 20, 
                a_start = 20, 
                a_finish = 30, 
                a_step = 1, 
                n_1 = 1000, 
                n_2 = 1000,
                n_trials = 20)
# Out:
# a = 20, b = 20, n = 2000, Spectral_k_means = 51.0% (59sec),
# a = 21, b = 20, n = 2000, Spectral_k_means = 51.0% (75sec),
# a = 22, b = 20, n = 2000, Spectral_k_means = 51.0% (85sec),
# a = 23, b = 20, n = 2000, Spectral_k_means = 57.0% (72sec),
# a = 24, b = 20, n = 2000, Spectral_k_means = 86.0% (52sec),
# a = 25, b = 20, n = 2000, Spectral_k_means = 100.0% (34sec),
# a = 26, b = 20, n = 2000, Spectral_k_means = 99.0% (37sec),
# a = 27, b = 20, n = 2000, Spectral_k_means = 100.0% (35sec),
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-cbde01e3d036> in <module>()
#       6                 n_1 = 1000,
#       7                 n_2 = 1000,
# ----> 8                 n_trials = 20)
#
# C:\Users\nord2\Google Диск\Python\GBM-unsupervised\classes.py in full_simulation(algo_list, a_start, a_finish, a_step, b, n_1, n_2, n_trials)
#     612                 time_dict = {A.__name__: 0 for A in algo_list}
#     613                 for i in range(n_trials):
# --> 614                         G = GBM_graph(n_1, n_2, a, b, disp = False)
#     615                         for A in algo_list:
#     616                                 start_time = time.time()
#
# C:\Users\nord2\Google Диск\Python\GBM-unsupervised\classes.py in __init__(self, n_1, n_2, a, b, eta, disp)
#      99                 self.av_deg_in = 2 * self.r_in * n_1
#     100                 self.av_deg_out = 2 * self.r_out * n_1
# --> 101                 self.adj_matrix = nx.adjacency_matrix(self)
#     102
#     103
#
# C:\Users\nord2\Anaconda3\lib\site-packages\networkx\linalg\graphmatrix.py in adjacency_matrix(G, nodelist, weight)
#     161     adjacency_spectrum
#     162     """
# --> 163     return nx.to_scipy_sparse_matrix(G, nodelist=nodelist, weight=weight)
#     164
#     165
#
# C:\Users\nord2\Anaconda3\lib\site-packages\networkx\convert_matrix.py in to_scipy_sparse_matrix(G, nodelist, dtype, weight, format)
#     781     index = dict(zip(nodelist, range(nlen)))
#     782     coefficients = zip(*((index[u], index[v], d.get(weight, 1))
# --> 783                          for u, v, d in G.edges(nodelist, data=True)
#     784                          if u in index and v in index))
#     785     try:
#
# C:\Users\nord2\Anaconda3\lib\site-packages\networkx\convert_matrix.py in <genexpr>(.0)
#     782     coefficients = zip(*((index[u], index[v], d.get(weight, 1))
#     783                          for u, v, d in G.edges(nodelist, data=True)
# --> 784                          if u in index and v in index))
#     785     try:
#     786         row, col, data = coefficients
#
# KeyboardInterrupt:

# %%
G = GBM_graph(n_1 = 2000, n_2 = 2000, a = 15, b = 6)

# %%
p = nx.shortest_path_length(G, source=0)

# %%
distances = set(p.values()) - set([0])
max_d = max(distances)
newBins = np.linspace(0, 1, 50)
for d in distances:
    sns.distplot([G.nodes[node]["coordinate"] for node in G.nodes if p[node] == d], 
                 label = "Distance " + str(d), 
                 color = 'blue', 
                 hist_kws=dict(alpha=1 - d/(max_d + 1)),
                 bins = newBins,
                 kde = False)
    plt.legend()

# %%
cluster_labels
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %%
G = GBM_graph(n_1 = 3000, n_2 = 3000, a = 12, b = 5)

# %%
k_means_analysis(G, n = 4000, portion = 0.02, spectrum_disp = True)
# Out:
# Total accuracy after k-means = 0.504

# %%
k_means_analysis(G, n = 4000, portion = 0.02, vectors = range(48, 60), c_norm_disp = True)
# Out:
# Total accuracy after k-means = 0.556

# %%
k_means_analysis(G, n = 4000, portion = 0.02, vectors = range(36,60), k = 20)
# Out:
# Total accuracy after k-means = 0.597

# %%
k_means_analysis(G, n = 4000, portion = 0.02, vectors = range(42,56), cut_disp = True)

# %%
G = GBM_graph(n_1 = 1000, n_2 = 1000, a = 18, b = 5)

# %%
k_means_analysis(G, vectors = [], vectors_disp = True)

# %%
Spectral_cutting(G,2)
# Out:
# Relabeled
# Accuracy = 0.850
# Accuracy cut labels = 0.850
# Not relabeled
# Accuracy = 0.830
# Accuracy cut labels = 0.734

# %%
s = Spectral_cutting_2(G)

# %%
s.accuracy
# Out:
# 0.7150510204081633

# %%
fs1000 = full_simulation([Spectral_k_means, Spectral_cutting_2, Spectral_cutting_3, Spectral_cutting_4, Spectral_cutting_8], 
                b = 5, 
                a_start = 7, 
                a_finish = 20, 
                a_step = 1, 
                n_1 = 1000, 
                n_2 = 1000,
                n_trials = 10)
# Out:
# a = 7, b = 5, n = 2000, Spectral_k_means = 57.0% (7sec), Spectral_cutting_2 = 61.0% (29sec), Spectral_cutting_3 = 61.0% (28sec), Spectral_cutting_4 = 61.0% (28sec), Spectral_cutting_8 = 61.0% (28sec),
# a = 8, b = 5, n = 2000, Spectral_k_means = 82.0% (10sec), Spectral_cutting_2 = 82.0% (34sec), Spectral_cutting_3 = 82.0% (34sec), Spectral_cutting_4 = 84.0% (33sec), Spectral_cutting_8 = 84.0% (33sec),
# a = 9, b = 5, n = 2000, Spectral_k_means = 78.0% (11sec), Spectral_cutting_2 = 87.0% (36sec), Spectral_cutting_3 = 87.0% (35sec), Spectral_cutting_4 = 87.0% (35sec), Spectral_cutting_8 = 85.0% (36sec),
# a = 10, b = 5, n = 2000, Spectral_k_means = 89.0% (9sec), Spectral_cutting_2 = 78.0% (36sec), Spectral_cutting_3 = 77.0% (36sec), Spectral_cutting_4 = 78.0% (36sec), Spectral_cutting_8 = 77.0% (37sec),
# a = 11, b = 5, n = 2000, Spectral_k_means = 89.0% (9sec), Spectral_cutting_2 = 83.0% (38sec), Spectral_cutting_3 = 85.0% (38sec), Spectral_cutting_4 = 84.0% (38sec), Spectral_cutting_8 = 84.0% (38sec),
# a = 12, b = 5, n = 2000, Spectral_k_means = 95.0% (9sec), Spectral_cutting_2 = 86.0% (38sec), Spectral_cutting_3 = 85.0% (38sec), Spectral_cutting_4 = 85.0% (39sec), Spectral_cutting_8 = 86.0% (39sec),
# a = 13, b = 5, n = 2000, Spectral_k_means = 95.0% (8sec), Spectral_cutting_2 = 82.0% (41sec), Spectral_cutting_3 = 83.0% (42sec), Spectral_cutting_4 = 83.0% (41sec), Spectral_cutting_8 = 83.0% (41sec),
# a = 14, b = 5, n = 2000, Spectral_k_means = 99.0% (8sec), Spectral_cutting_2 = 86.0% (43sec), Spectral_cutting_3 = 87.0% (43sec), Spectral_cutting_4 = 86.0% (43sec), Spectral_cutting_8 = 86.0% (43sec),
# a = 15, b = 5, n = 2000, Spectral_k_means = 96.0% (9sec), Spectral_cutting_2 = 79.0% (42sec), Spectral_cutting_3 = 79.0% (43sec), Spectral_cutting_4 = 79.0% (44sec), Spectral_cutting_8 = 80.0% (43sec),
# a = 16, b = 5, n = 2000, Spectral_k_means = 100.0% (8sec), Spectral_cutting_2 = 84.0% (45sec), Spectral_cutting_3 = 86.0% (46sec), Spectral_cutting_4 = 87.0% (45sec), Spectral_cutting_8 = 86.0% (46sec),
# a = 17, b = 5, n = 2000, Spectral_k_means = 100.0% (9sec), Spectral_cutting_2 = 83.0% (49sec), Spectral_cutting_3 = 81.0% (49sec), Spectral_cutting_4 = 81.0% (49sec), Spectral_cutting_8 = 83.0% (49sec),
# a = 18, b = 5, n = 2000, Spectral_k_means = 100.0% (9sec), Spectral_cutting_2 = 79.0% (49sec), Spectral_cutting_3 = 80.0% (50sec), Spectral_cutting_4 = 79.0% (50sec), Spectral_cutting_8 = 80.0% (50sec),
# a = 19, b = 5, n = 2000, Spectral_k_means = 100.0% (10sec), Spectral_cutting_2 = 91.0% (49sec), Spectral_cutting_3 = 91.0% (49sec), Spectral_cutting_4 = 91.0% (49sec), Spectral_cutting_8 = 89.0% (49sec),
