# %% [markdown]
# ## Analysis of algorithms that make exact recovery of the cluster structure in GBM
# Model description is [here](https://arxiv.org/pdf/1709.05510.pdf)
#
# Candidate algorithms are:
# 1. Motif-counting algorithm (from the above paper) and its modification from [here](https://arxiv.org/abs/1804.05013)
# 2. Spectral clustering with a smart choice of the optimal eigenvectors (k-means around optimal value)
# 3. Expansion algorithm described in my draft [here](https://www.overleaf.com/project/5e9483ae085e6600014af805)
#
# Last update: 21/05/2020

# %% [markdown]
# ### This notebook uses the classes.py file where principal classes and functions are defined
#
# File classes.py is on autoreload

# %%
import pandas as pd
import numpy as np
import networkx as nx
import random
import matplotlib.pyplot as plt
import seaborn as sns
from classes import GBM_graph, Motif_Counting, Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means, Spectral_clustering, Laplacian_regularization, Common_neigbours_labeling, simulation, full_simulation, k_means_analysis
import tqdm
import time 
import warnings
import copy
warnings.filterwarnings("ignore")
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
G = GBM_graph(n_1 = 500, n_2 = 500, a = 30, b = 7, disp = False)

# %%
m = Motif_Counting(G)

# %%
m.accuracy
# Out:
# 1.0

# %%
fs = full_simulation([Motif_Counting, Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means],
                    n_1 = 500, 
                    n_2 = 500,
                    a_start = 20,
                    a_finish = 31,
                    a_step = 1,
                    b = 7,
                    n_trials = 10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-28ee627305ad> in <module>
#       6                     a_step = 1,
#       7                     b = 7,
# ----> 8                     n_trials = 10)
#
# /run/netsop/u/home-sam/home/abobu/Documents/python-notebooks/GBM-unsupervised/classes.py in full_simulation(algo_list, a_start, a_finish, a_step, b, n_1, n_2, n_trials)
#     899         time_dict = {A.__name__: 0 for A in algo_list}
#     900         for i in range(n_trials):
# --> 901             G = GBM_graph(n_1, n_2, a, b, disp = False)
#     902             for A in algo_list:
#     903                 start_time = time.time()
#
# /run/netsop/u/home-sam/home/abobu/Documents/python-notebooks/GBM-unsupervised/classes.py in __init__(self, n_1, n_2, a, b, eta, disp)
#      93         for i in range(n):
#      94             j = (i+1) % n
# ---> 95             while ( torusDistance( positions[ nodesIndexSortedByGeography[i] ], positions[ nodesIndexSortedByGeography[j] ] ) < max(self.r_in, self.r_out) ) :
#      96                 if( torusDistance( positions[ nodesIndexSortedByGeography[i] ], positions[ nodesIndexSortedByGeography[j] ] ) < cutoffMatrix[self.ground_labels[ nodesIndexSortedByGeography[i] ] - 1, self.ground_labels[ nodesIndexSortedByGeography[j] ] - 1  ] ) :
#      97                     edges.append( ( nodesIndexSortedByGeography[i], nodesIndexSortedByGeography[j] ) )
#
# KeyboardInterrupt:

# %%
G = GBM_graph(n_1 = 1000, n_2 = 1000, a = 15, b = 5)
n = G.number_of_nodes()
labeled_set = random.sample(list(G.nodes), int(0.02 * n))

# %%
k_means_analysis(G, vectors = [], vectors_disp = True, sigma = 0.5)

# %%
k_means_analysis(G, vectors = range(10, 17), cut_disp = True)

# %%
labeled_set = [u for u in G if G.nodes[u]['coordinate'] > 0.5 and G.nodes[u]['coordinate'] < 0.52]

# %%
l = Laplacian_regularization(G, [i for i in range(40, 60)], labeled_set = labeled_set, eta = 0.02)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-cd086be52aeb> in <module>
# ----> 1 l = Laplacian_regularization(G, [i for i in range(40, 60)], labeled_set = labeled_set, eta = 0.02)
#
# /run/netsop/u/home-sam/home/abobu/Documents/python-notebooks/GBM-unsupervised/classes.py in __init__(self, G, vec_idxs, labeled_set, eta)
#     862
#     863         # The algorithm
# --> 864         self.analysis(G, idxs = vec_idxs, labeled_set = labeled_set, portion = 0.02)
#     865
#     866
#
# /run/netsop/u/home-sam/home/abobu/Documents/python-notebooks/GBM-unsupervised/classes.py in analysis(self, G, idxs, labeled_set, portion)
#     822         vals, vecs = sparse.linalg.eigs(laplacian_matrix.asfptype(), k=int(portion * n), which = 'SM')
#     823
# --> 824         vecs = [vecs[:, i] for i in idxs]
#     825         print(len(vecs[0]))
#     826         vals = vals[idxs]
#
# /run/netsop/u/home-sam/home/abobu/Documents/python-notebooks/GBM-unsupervised/classes.py in <listcomp>(.0)
#     822         vals, vecs = sparse.linalg.eigs(laplacian_matrix.asfptype(), k=int(portion * n), which = 'SM')
#     823
# --> 824         vecs = [vecs[:, i] for i in idxs]
#     825         print(len(vecs[0]))
#     826         vals = vals[idxs]
#
# IndexError: index 40 is out of bounds for axis 1 with size 40
