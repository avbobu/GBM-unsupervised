# %% [markdown]
# ## Analysis of algorithms that make exact recovery of the cluster structure in GBM
# Model description is [here](https://arxiv.org/pdf/1709.05510.pdf)
#
# Candidate algorithms are:
# 1. Motif-counting algorithm (from the above paper) and its modification from [here](https://arxiv.org/abs/1804.05013)
# 2. Spectral clustering with a smart choice of the optimal eigenvectors (k-means around optimal value)
# 3. Expansion algorithm described in my draft [here](https://www.overleaf.com/project/5e9483ae085e6600014af805)
#
# Last update: 21/05/2020

# %% [markdown]
# ### This notebook uses the classes.py file where principal classes and functions are defined
#
# File classes.py is on autoreload

# %%
import pandas as pd
import numpy as np
import networkx as nx
import random
import matplotlib.pyplot as plt
import seaborn as sns
from classes import GBM_graph, Motif_Counting, Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means, Spectral_clustering, Laplacian_regularization, Common_neigbours_labeling, simulation, full_simulation, k_means_analysis
import tqdm
import time 
import warnings
import copy
warnings.filterwarnings("ignore")
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
G = GBM_graph(n_1 = 500, n_2 = 500, a = 30, b = 7, disp = False)

# %%
m = Motif_Counting(G)
# Out:
# 2

# %%
m.accuracy
# Out:
# 1.0

# %%
fs = full_simulation([Motif_Counting, Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means],
                    n_1 = 500, 
                    n_2 = 500,
                    a_start = 20,
                    a_finish = 31,
                    a_step = 1,
                    b = 7,
                    n_trials = 10)
# Out:
# a = 20, b = 7, n = 1000, Motif_Counting = 50.0% (42sec), Motif_Counting_second_paper = 100.0% (39sec), Expansion_algorithm = 100.0% (10sec), Spectral_k_means = 100.0% (4sec),
# a = 21, b = 7, n = 1000, Motif_Counting = 50.0% (44sec), Motif_Counting_second_paper = 100.0% (43sec), Expansion_algorithm = 100.0% (11sec), Spectral_k_means = 100.0% (4sec),
# a = 22, b = 7, n = 1000, Motif_Counting = 55.0% (45sec), Motif_Counting_second_paper = 100.0% (44sec), Expansion_algorithm = 100.0% (12sec), Spectral_k_means = 100.0% (5sec),
# a = 23, b = 7, n = 1000, Motif_Counting = 50.0% (50sec), Motif_Counting_second_paper = 100.0% (51sec), Expansion_algorithm = 100.0% (14sec), Spectral_k_means = 95.0% (5sec),
# a = 24, b = 7, n = 1000, Motif_Counting = 60.0% (54sec), Motif_Counting_second_paper = 100.0% (53sec), Expansion_algorithm = 100.0% (14sec), Spectral_k_means = 96.0% (5sec),
# a = 25, b = 7, n = 1000, Motif_Counting = 85.0% (55sec), Motif_Counting_second_paper = 100.0% (53sec), Expansion_algorithm = 100.0% (14sec), Spectral_k_means = 100.0% (4sec),
# a = 26, b = 7, n = 1000, Motif_Counting = 95.0% (57sec), Motif_Counting_second_paper = 100.0% (56sec), Expansion_algorithm = 100.0% (15sec), Spectral_k_means = 100.0% (5sec),
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-e4ef36d14012> in <module>()
#       6                     a_step = 1,
#       7                     b = 7,
# ----> 8                     n_trials = 10)
#
# C:\Users\nord2\Google Диск\Python\GBM-unsupervised\classes.py in full_simulation(algo_list, a_start, a_finish, a_step, b, n_1, n_2, n_trials)
#     753                         for A in algo_list:
#     754                                 start_time = time.time()
# --> 755                                 alg_res = A(G)
#     756                                 # print(acc)
#     757                                 # G_dict.update({(a,b,n_1+n_2): sim['graphs']})
#
# C:\Users\nord2\Google Диск\Python\GBM-unsupervised\classes.py in __init__(self, G)
#     234         def __init__(self, G):
#     235                 self.accuracy = 0
# --> 236                 self.motif_counting_analysis(G, G.r_in, G.r_out)
#     237
#     238 #### Some auxuliary functions for the motif-counting algo
#
# C:\Users\nord2\Google Диск\Python\GBM-unsupervised\classes.py in motif_counting_analysis(self, G, r_in, r_out)
#     218                 G_mst.add_nodes_from(Gc)
#     219                 for ed in Gc.edges():
# --> 220                     if (calcmot1(Gc, ed)>=motif1(r_in,r_out,size1,size2)):
#     221                         G_mst.add_edge(ed[0],ed[1])
#     222
#
# C:\Users\nord2\Google Диск\Python\GBM-unsupervised\classes.py in calcmot1(Gc, edge)
#     262
#     263 def calcmot1(Gc, edge):
# --> 264         return len(set(Gc.neighbors(edge[0])).intersection(set(Gc.neighbors(edge[1]))))
#     265
#     266 #### The new algorithm of guys from UMASS
#
# KeyboardInterrupt:

# %%
G = GBM_graph(n_1 = 1000, n_2 = 1000, a = 15, b = 5)
n = G.number_of_nodes()
labeled_set = random.sample(list(G.nodes), int(0.02 * n))

# %%
k_means_analysis(G, vectors = [], vectors_disp = True, sigma = 0.5)
# Out:
# [-2.68882139e-16+0.j  1.38294424e-02+0.j  1.90463913e-02+0.j
#   6.05659488e-02+0.j  6.72353312e-02+0.j  1.29910587e-01+0.j
#   1.52217158e-01+0.j  2.22128542e-01+0.j  2.61077625e-01+0.j
#   3.53615555e-01+0.j  3.61313895e-01+0.j  4.75482569e-01+0.j
#   4.82546610e-01+0.j  5.03174817e-01+0.j  5.23962960e-01+0.j
#   5.24712629e-01+0.j  5.64756490e-01+0.j  5.67361159e-01+0.j
#   6.01262536e-01+0.j  6.11162625e-01+0.j  6.33130876e-01+0.j
#   6.41523525e-01+0.j  7.10634242e-01+0.j  7.22864008e-01+0.j
#   7.28769324e-01+0.j  7.33161761e-01+0.j  8.15485954e-01+0.j
#   8.17136395e-01+0.j  8.28038706e-01+0.j  8.32859828e-01+0.j
#   8.47882876e-01+0.j  8.49942291e-01+0.j  8.51728151e-01+0.j
#   8.56072086e-01+0.j  8.62544320e-01+0.j  8.64840616e-01+0.j
#   8.68396757e-01+0.j  8.71635991e-01+0.j  8.79542111e-01+0.j
#   8.83979605e-01+0.j]

# %%
k_means_analysis(G, vectors = range(35, 43), cut_disp = True)

# %%
labeled_set = [u for u in G if G.nodes[u]['coordinate'] > 0.5 and G.nodes[u]['coordinate'] < 0.52]

# %%
l = Laplacian_regularization(G, [i for i in range(40, 60)], labeled_set = labeled_set, eta = 0.02)
# Out:
# 8000
# Optimization terminated successfully.
#          Current function value: 0.206116
#          Iterations: 107
#          Function evaluations: 2486
#          Gradient evaluations: 113
# [  22.84006858 -142.97728855  112.2873129   -45.42578019   45.26928476
#  -134.67043788  391.50540085   61.13209264  242.00467485  270.09323614
#   114.11088219  -75.1980166   -97.34897634   52.92988738  -78.14702241
#   260.64469769  -28.664751   -127.65507521 -387.58766821  -12.94133232]
# Accuracy = 0.552
