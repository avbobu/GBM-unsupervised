# %% [markdown]
# ## Analysis of algorithms that make exact recovery of the cluster structure in GBM
# Model description is [here](https://arxiv.org/pdf/1709.05510.pdf)
#
# Candidate algorithms are:
# 1. Motif-counting algorithm (from the above paper)
# 2. Spectral clustering
#
# Last update: 26/09/2019

# %% [markdown]
# ### This notebook uses the classes.py file where principal classes and functions are defined
#
# File classes.py is on autoreload

# %%
import pandas as pd
import numpy as np
import networkx as nx
import random
import matplotlib.pyplot as plt
import seaborn as sns
from classes import GBM_graph, Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means, Common_neigbours_labeling, simulation, full_simulation
import tqdm
import time 
import warnings
import copy
warnings.filterwarnings("ignore")
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fs5_500 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 500, 
                          n_2 = 500, 
                          a_start = 7, 
                          a_finish = 21, 
                          a_step = 1, 
                          b = 5,
                          n_trials = 20)
# Out:
# a = 7, b = 5, Motif_Counting_second_paper = 53.0% (22sec), Expansion_algorithm = 50.0% (0sec), Spectral_k_means = 56.0% (8sec),
# a = 8, b = 5, Motif_Counting_second_paper = 52.0% (26sec), Expansion_algorithm = 50.0% (0sec), Spectral_k_means = 94.0% (10sec),
# a = 9, b = 5, Motif_Counting_second_paper = 58.0% (28sec), Expansion_algorithm = 50.0% (0sec), Spectral_k_means = 96.0% (10sec),
# a = 10, b = 5, Motif_Counting_second_paper = 83.0% (32sec), Expansion_algorithm = 51.0% (0sec), Spectral_k_means = 92.0% (11sec),
# a = 11, b = 5, Motif_Counting_second_paper = 93.0% (39sec), Expansion_algorithm = 53.0% (0sec), Spectral_k_means = 96.0% (11sec),
# a = 12, b = 5, Motif_Counting_second_paper = 90.0% (41sec), Expansion_algorithm = 57.0% (0sec), Spectral_k_means = 99.0% (11sec),
# a = 13, b = 5, Motif_Counting_second_paper = 90.0% (47sec), Expansion_algorithm = 71.0% (0sec), Spectral_k_means = 100.0% (12sec),
# a = 14, b = 5, Motif_Counting_second_paper = 98.0% (50sec), Expansion_algorithm = 86.0% (0sec), Spectral_k_means = 100.0% (11sec),
# a = 15, b = 5, Motif_Counting_second_paper = 98.0% (53sec), Expansion_algorithm = 96.0% (1sec), Spectral_k_means = 100.0% (12sec),
# a = 16, b = 5, Motif_Counting_second_paper = 93.0% (57sec), Expansion_algorithm = 96.0% (0sec), Spectral_k_means = 98.0% (14sec),
# a = 17, b = 5, Motif_Counting_second_paper = 95.0% (59sec), Expansion_algorithm = 100.0% (0sec), Spectral_k_means = 100.0% (12sec),
# a = 18, b = 5, Motif_Counting_second_paper = 95.0% (71sec), Expansion_algorithm = 100.0% (0sec), Spectral_k_means = 100.0% (12sec),
# a = 19, b = 5, Motif_Counting_second_paper = 98.0% (74sec), Expansion_algorithm = 100.0% (0sec), Spectral_k_means = 93.0% (13sec),
# a = 20, b = 5, Motif_Counting_second_paper = 95.0% (75sec), Expansion_algorithm = 100.0% (0sec), Spectral_k_means = 96.0% (13sec),

# %%
fs5_1000 = full_simulation([Motif_Counting_second_paper, Expansion_algorithm, Spectral_k_means], 
                          n_1 = 1000, 
                          n_2 = 1000, 
                          a_start = 7, 
                          a_finish = 21, 
                          a_step = 1, 
                          b = 5,
                          n_trials = 20)
# Out:
# a = 7, b = 5, Motif_Counting_second_paper = 53.0% (52sec), Expansion_algorithm = 50.0% (0sec), Spectral_k_means = 68.0% (14sec),
# a = 8, b = 5, Motif_Counting_second_paper = 52.0% (59sec), Expansion_algorithm = 50.0% (0sec), Spectral_k_means = 86.0% (18sec),
# a = 9, b = 5, Motif_Counting_second_paper = 60.0% (66sec), Expansion_algorithm = 50.0% (0sec), Spectral_k_means = 91.0% (17sec),
# a = 10, b = 5, Motif_Counting_second_paper = 82.0% (72sec), Expansion_algorithm = 51.0% (0sec), Spectral_k_means = 90.0% (18sec),
# a = 11, b = 5, Motif_Counting_second_paper = 92.0% (80sec), Expansion_algorithm = 52.0% (0sec), Spectral_k_means = 93.0% (17sec),
# a = 12, b = 5, Motif_Counting_second_paper = 90.0% (87sec), Expansion_algorithm = 55.0% (0sec), Spectral_k_means = 89.0% (19sec),
# a = 13, b = 5, Motif_Counting_second_paper = 97.0% (96sec), Expansion_algorithm = 63.0% (1sec), Spectral_k_means = 98.0% (19sec),
# a = 14, b = 5, Motif_Counting_second_paper = 92.0% (103sec), Expansion_algorithm = 84.0% (1sec), Spectral_k_means = 99.0% (19sec),
# a = 15, b = 5, Motif_Counting_second_paper = 98.0% (114sec), Expansion_algorithm = 97.0% (2sec), Spectral_k_means = 98.0% (19sec),
# a = 16, b = 5, Motif_Counting_second_paper = 93.0% (119sec), Expansion_algorithm = 100.0% (2sec), Spectral_k_means = 99.0% (18sec),
# a = 17, b = 5, Motif_Counting_second_paper = 98.0% (128sec), Expansion_algorithm = 100.0% (1sec), Spectral_k_means = 98.0% (19sec),
# a = 18, b = 5, Motif_Counting_second_paper = 95.0% (137sec), Expansion_algorithm = 100.0% (1sec), Spectral_k_means = 100.0% (18sec),
# a = 19, b = 5, Motif_Counting_second_paper = 93.0% (148sec), Expansion_algorithm = 100.0% (1sec), Spectral_k_means = 98.0% (21sec),
# a = 20, b = 5, Motif_Counting_second_paper = 95.0% (167sec), Expansion_algorithm = 100.0% (2sec), Spectral_k_means = 98.0% (22sec),

# %%
G = GBM_graph(n_1 = 500, n_2 = 500, a = 15, b = 7, disp = False)

# %%
Common_neigbours_labeling(G, eta = 0.01)
# Out:
# 0.619

# %%
fs0_05_1000 = full_simulation([Common_neigbours_labeling], 
                          n_1 = 1000, 
                          n_2 = 1000, 
                          a_start = 7, 
                          a_finish = 21, 
                          a_step = 1, 
                          b = 7,
                          n_trials = 20)
# Out:
# a = 7, b = 7, Common_neigbours_labeling = 52.0% (1sec),
# a = 8, b = 7, Common_neigbours_labeling = 58.0% (1sec),
# a = 9, b = 7, Common_neigbours_labeling = 63.0% (1sec),
# a = 10, b = 7, Common_neigbours_labeling = 67.0% (1sec),
# a = 11, b = 7, Common_neigbours_labeling = 73.0% (1sec),
# a = 12, b = 7, Common_neigbours_labeling = 77.0% (1sec),
# a = 13, b = 7, Common_neigbours_labeling = 80.0% (1sec),
# a = 14, b = 7, Common_neigbours_labeling = 83.0% (1sec),
# a = 15, b = 7, Common_neigbours_labeling = 86.0% (1sec),
# a = 16, b = 7, Common_neigbours_labeling = 89.0% (1sec),
# a = 17, b = 7, Common_neigbours_labeling = 91.0% (1sec),
# a = 18, b = 7, Common_neigbours_labeling = 93.0% (1sec),
# a = 19, b = 7, Common_neigbours_labeling = 94.0% (2sec),
# a = 20, b = 7, Common_neigbours_labeling = 96.0% (2sec),

# %%
fs0_05_1000 = full_simulation([Common_neigbours_labeling], 
                          n_1 = 1000, 
                          n_2 = 1000, 
                          a_start = 5, 
                          a_finish = 21, 
                          a_step = 1, 
                          b = 5,
                          n_trials = 20)
# Out:
# a = 5, b = 5, Common_neigbours_labeling = 52.0% (1sec),
# a = 6, b = 5, Common_neigbours_labeling = 58.0% (1sec),
# a = 7, b = 5, Common_neigbours_labeling = 64.0% (1sec),
# a = 8, b = 5, Common_neigbours_labeling = 69.0% (1sec),
# a = 9, b = 5, Common_neigbours_labeling = 74.0% (1sec),
# a = 10, b = 5, Common_neigbours_labeling = 77.0% (1sec),
# a = 11, b = 5, Common_neigbours_labeling = 82.0% (1sec),
# a = 12, b = 5, Common_neigbours_labeling = 84.0% (1sec),
# a = 13, b = 5, Common_neigbours_labeling = 88.0% (1sec),
# a = 14, b = 5, Common_neigbours_labeling = 90.0% (1sec),
# a = 15, b = 5, Common_neigbours_labeling = 91.0% (1sec),
# a = 16, b = 5, Common_neigbours_labeling = 93.0% (1sec),
# a = 17, b = 5, Common_neigbours_labeling = 94.0% (1sec),
# a = 18, b = 5, Common_neigbours_labeling = 96.0% (1sec),
# a = 19, b = 5, Common_neigbours_labeling = 97.0% (1sec),
# a = 20, b = 5, Common_neigbours_labeling = 97.0% (2sec),

# %%
fs0_05_25000 = full_simulation([Common_neigbours_labeling], 
                          n_1 = 2500, 
                          n_2 = 2500, 
                          a_start = 5, 
                          a_finish = 21, 
                          a_step = 1, 
                          b = 5,
                          n_trials = 10)
# Out:
# a = 5, b = 5, Common_neigbours_labeling = 52.0% (2sec),
# a = 6, b = 5, Common_neigbours_labeling = 58.0% (2sec),
# a = 7, b = 5, Common_neigbours_labeling = 64.0% (2sec),
# a = 8, b = 5, Common_neigbours_labeling = 70.0% (2sec),
# a = 9, b = 5, Common_neigbours_labeling = 76.0% (2sec),
# a = 10, b = 5, Common_neigbours_labeling = 79.0% (2sec),
# a = 11, b = 5, Common_neigbours_labeling = 84.0% (2sec),
# a = 12, b = 5, Common_neigbours_labeling = 86.0% (2sec),
# a = 13, b = 5, Common_neigbours_labeling = 90.0% (2sec),
# a = 14, b = 5, Common_neigbours_labeling = 92.0% (2sec),
# a = 15, b = 5, Common_neigbours_labeling = 93.0% (2sec),
# a = 16, b = 5, Common_neigbours_labeling = 95.0% (2sec),
# a = 17, b = 5, Common_neigbours_labeling = 95.0% (3sec),
# a = 18, b = 5, Common_neigbours_labeling = 96.0% (3sec),
# a = 19, b = 5, Common_neigbours_labeling = 97.0% (3sec),
# a = 20, b = 5, Common_neigbours_labeling = 98.0% (3sec),
